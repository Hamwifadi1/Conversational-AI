# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamwifadi1/Conversational-AI-/blob/main/WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install WordCloud**

# %%
# !pip install wordcloud

# %% [markdown]
# # **The Required Functions**

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %% [markdown]
# # **Connect With Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open("/content/drive/MyDrive/JaneEyre.txt", "r") as file:
  text = file.read()

# %% [markdown]
# # **Create A WordCloud Object**

# %%
wordcloud = WordCloud(
width=800,
height=400,
background_color="white",
stopwords=set(STOPWORDS),
min_font_size=10,
).generate(text)

# %%
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # **WordCloud Customization**

# %%
wordcloud_customized = WordCloud(
    width=800,
    height=400,
    background_color='whitesmoke',
    colormap='gray',
    max_words=20,
    stopwords=stop_words.union({'will', 'now'})
).generate(text)

# %%
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud_customized)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # **Mask Parameter**

# %%
mask_path = '/content/drive/MyDrive/Colab Notebooks/Mask.png'
mask_image = np.array(Image.open(mask_path))

# %%
wordcloud_masked = WordCloud(
    background_color='white',
    colormap='Blues',
    max_words=100,
    mask=mask_image,
    contour_color='black',  # Optional: Adds a contour around the mask
    contour_width=1
).generate(text)

# Display the word cloud
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud_masked, interpolation='bilinear')
plt.axis('off')
plt.show()
